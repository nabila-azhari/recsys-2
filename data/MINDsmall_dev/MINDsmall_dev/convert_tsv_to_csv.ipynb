# %%
import pandas as pd

# baca file TSV
df = pd.read_csv(r"C:\Users\USER\Desktop\recsys-2\recsys-2\data\MINDsmall_dev\MINDsmall_dev\behaviors.tsv", sep="\t")

# simpan sebagai CSV
df.to_csv(r"C:\Users\USER\Desktop\recsys-2\recsys-2\data\MINDsmall_dev\MINDsmall_dev\behaviors.csv", index=False)

print("konversi selesai!")
# Out:
# konversi selesai!

# %%
import pandas as pd

# baca file TSV
df = pd.read_csv(r"C:\Users\USER\Desktop\recsys-2\recsys-2\data\MINDsmall_dev\MINDsmall_dev\news.tsv", sep="\t")

# simpan sebagai CSV
df.to_csv(r"C:\Users\USER\Desktop\recsys-2\recsys-2\data\MINDsmall_dev\MINDsmall_dev\news.csv", index=False)

print("konversi selesai!")
# Out:
# konversi selesai!
